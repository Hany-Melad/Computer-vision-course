# %% [markdown]
# # Image Representation & Classification

# %% [markdown]
# ### 1- Computer Vision Pipeline

# %% [markdown]
# A computer vision pipeline is a series of steps that most computer vision applications will go through

# %% [markdown]
# ![screen-shot-2017-03-13-at-12.36.54-pm.png](attachment:screen-shot-2017-03-13-at-12.36.54-pm.png)

# %% [markdown]
# ##### 1.1- Standardizing Data

# %% [markdown]
# ![screen-shot-2018-04-23-at-4.05.20-pm.png](attachment:screen-shot-2018-04-23-at-4.05.20-pm.png)

# %% [markdown]
# ![stop-sign-classification.png](attachment:stop-sign-classification.png)

# %% [markdown]
# ### 2- Training a Neural Network

# %% [markdown]
# Training a Neural Network
# To train a computer vision neural network, we typically `provide sets of labelled images`, which we can compare to the `predicted output label `

# %% [markdown]
# ![screen-shot-2018-04-23-at-4.14.19-pm.png](attachment:screen-shot-2018-04-23-at-4.14.19-pm.png)

# %% [markdown]
# ## 3- Separating Data

# %% [markdown]
# neural network separates two kinds of data based on their unique shapes (the different shapes of the eyes and mouth, in the case of a smile and smirk)
# Deep neural networks are similar, only they can draw multiple and more complex separation lines in the sand

# %% [markdown]
# ![screen-shot-2018-03-23-at-3.57.38-pm.png](attachment:screen-shot-2018-03-23-at-3.57.38-pm.png)

# %% [markdown]
# ![screen-shot-2018-03-23-at-4.04.35-pm.png](attachment:screen-shot-2018-03-23-at-4.04.35-pm.png)

# %% [markdown]
# ![screen-shot-2018-03-23-at-4.02.58-pm.png](attachment:screen-shot-2018-03-23-at-4.02.58-pm.png)

# %% [markdown]
# ![screen-shot-2018-03-23-at-4.05.32-pm.png](attachment:screen-shot-2018-03-23-at-4.05.32-pm.png)

# %% [markdown]
# ## 3- Images as Numerical Data

# %% [markdown]
# black and white images  Vs Colored images

# %% [markdown]
# ![images.jpg](attachment:images.jpg)

# %% [markdown]
# 4- notebook blue background
